# %% [markdown]
# **bar graph**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline     # IPython 매직 메서드

# graph data
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# axis drawing
fig = plt.figure()  # 도화지(그래프) 객체 생성
ax1 = fig.add_subplot(1,1,1) # figure()객체에 add_subplot 메서드를 이용해 축을 그림.  

# graph drawing
ax1.bar(subject, points)

# label, title
plt.xlabel('Subject')
plt.ylabel('Points')
plt.title("Test Result")

# show
plt.savefig('./barplot.png')   # output graph to image
plt.show()                     # output graph to screen

# %% [markdown]
# * [IPython 매직 메서드](https://studymake.tistory.com/601)

# %% [markdown]
# **line graph**

# %% [markdown]
# [과거 아마존 주가 데이터 사용](https://studymake.tistory.com/601)

# %%
from datetime import datetime
import pandas as pd
import os

# graph data
csv_path = os.getenv("HOME") + "/aiffel/data_visualization/data/AMZN.csv"
data = pd.read_csv(csv_path, index_col=0, parse_dates=True)
price = data['Close']

# 축 그리기 및 좌표축 설정
fig = plt.figure()
ax = fig.add_subplot(1,1,1)  # add_subplot()
price.plot(ax=ax, style='black')
plt.ylim([1600, 2200])
plt.xlim(['2019-05-01', '2020-03-01'])

# 주석달기
important_data = [(datetime(2019, 6, 3), "Low Price"),(datetime(2020, 2, 19), "Peak Price")]
for d, label in important_data:
    ax.annotate(label, xy=(d, price.asof(d)+10), # 주석을 달 좌표(x,y)
                xytext=(d,price.asof(d)+100), # 주석 텍스트가 위차할 좌표(x,y)
                arrowprops=dict(facecolor='red')) # 화살표 추가 및 색 설정

# 그리드, 타이틀 달기
plt.grid()
ax.set_title('StockPrice')

# 보여주기
plt.show()

# %%
# plt.plot()의 인자로 x데이터, y데이터, marker option, color 등의 parameter 사용 가능.
import numpy as np
import matplotlib.pyplot as plt 
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x), 'o')
plt.plot(x, np.cos(x), '--', color='black')
plt.show()
